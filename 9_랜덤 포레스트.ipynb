# %% [markdown]
# # **1. hotel 데이터셋 살펴보기**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
hotel_df = pd.read_csv('/content/drive/MyDrive/파이썬AI프로젝트202307/4_머신러닝과 딥러닝/Data/hotel.csv')

# %%
hotel_df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
pd.set_option('display.max_columns', 100)

# %%
hotel_df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %%
hotel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# * hotel: 호텔 종류
# * is_canceled: 취소 여부
# * lead_time: 예약 시점으로부터 체크인 될 때까지의 기간(얼마나 미리 예약했는지)
# * arrival_date_year: 예약 연도
# * arrival_date_month: 예약 월
# * arrival_date_week_number: 예약 주
# * arrival_date_day_of_month: 예약 일
# * stays_in_weekend_nights: 주말을 끼고 얼마나 묶었는지
# * stays_in_week_nights: 평일을 끼고 얼마나 묶었는지
# * adults: 성인 인원수
# * children: 어린이 인원수
# * babies: 아기 인원수
# * meal: 식사 형태
# * country: 지역
# * distribution_channel: 어떤 방식으로 예약했는지
# * is_repeated_guest: 예약한적이 있는 고객인지
# * previous_cancellations: 몇번 예약을 취소했었는지
# * previous_bookings_not_canceled: 예약을 취소하지 않고 정상 숙박한 횟수
# * reserved_room_type: 희망한 룸타입
# * assigned_room_type: 실제 배정된 룸타입
# * booking_changes: 예약 후 서비스가 몇번 변경되었는지
# * deposit_type: 요금 납부 방식
# * days_in_waiting_list: 예약을 위해 기다린 날짜
# * customer_type: 고객 타입
# * adr: 특정일에 높아지거나 낮아지는 가격
# * required_car_parking_spaces: 주차공간을 요구했는지
# * total_of_special_requests: 특별한 별도의 요청사항이 있는지
# * reservation_status_date: 예약한 날짜
# * name: 이름
# * email: 이메일
# * phone-number: 전화번호
# * credit_card: 카드번호

# %%
hotel_df.drop(['name', 'email', 'phone-number', 'credit_card', 'reservation_status_date'], axis = 1, inplace=True)

# %%
hotel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 27 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
hotel_df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
sns.displot(hotel_df['lead_time'])

# %%
sns.boxplot(y=hotel_df['lead_time'])
# Out:
# <Axes: ylabel='lead_time'>

# %%
sns.barplot(x=hotel_df['distribution_channel'], y = hotel_df['is_canceled'])
# Out:
# <Axes: xlabel='distribution_channel', ylabel='is_canceled'>

# %%
hotel_df['distribution_channel'].value_counts()
# Out:
# TA/TO        97870
# Direct       14645
# Corporate     6677
# GDS            193
# Undefined        5
# Name: distribution_channel, dtype: int64

# %%
sns.barplot(x=hotel_df['hotel'], y = hotel_df['is_canceled'])
# Out:
# <Axes: xlabel='hotel', ylabel='is_canceled'>

# %%
sns.barplot(x=hotel_df['arrival_date_year'], y = hotel_df['is_canceled'])
# Out:
# <Axes: xlabel='arrival_date_year', ylabel='is_canceled'>

# %%
plt.figure(figsize = (15, 5))
sns.barplot(x=hotel_df['arrival_date_month'], y = hotel_df['is_canceled'])
# Out:
# <Axes: xlabel='arrival_date_month', ylabel='is_canceled'>

# %%
import calendar

# %%
print(calendar.month_name[0])
print(calendar.month_name[1])
print(calendar.month_name[2])
print(calendar.month_name[3])
# Out:
# January
# February
# March

# %%
months = []

for i in range(1, 13):
  months.append(calendar.month_name[i])

months
# Out:
# ['January',
#  'February',
#  'March',
#  'April',
#  'May',
#  'June',
#  'July',
#  'August',
#  'September',
#  'October',
#  'November',
#  'December']

# %%
# 1월부터 나오게 수정!
plt.figure(figsize = (15, 5))
sns.barplot(x=hotel_df['arrival_date_month'], y = hotel_df['is_canceled'], order = months)
# Out:
# <Axes: xlabel='arrival_date_month', ylabel='is_canceled'>

# %%
sns.barplot(x=hotel_df['is_repeated_guest'], y = hotel_df['is_canceled'])
# Out:
# <Axes: xlabel='is_repeated_guest', ylabel='is_canceled'>

# %%
sns.barplot(x=hotel_df['deposit_type'], y = hotel_df['is_canceled'])
# Out:
# <Axes: xlabel='deposit_type', ylabel='is_canceled'>

# %%
plt.figure(figsize = (15, 15))
# corr() : 열들 간의 상관관계를 계산하는 함수, 피어슨 상관계수
# -1 ~ 1 까지의 범위를 가지며 0에 가까울수록 두 변수의 상관관계가 없거나 매우 약한 관계
sns.heatmap(hotel_df.corr(), cmap = 'coolwarm', vmax = 1, vmin = -1, annot = True)
# Out:
# <ipython-input-25-8ed9bca4584e>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(hotel_df.corr(), cmap = 'coolwarm', vmax = 1, vmin = -1, annot = True)
# <Axes: >

# %%
hotel_df.isna().mean()
# Out:
# hotel                             0.000000
# is_canceled                       0.000000
# lead_time                         0.000000
# arrival_date_year                 0.000000
# arrival_date_month                0.000000
# arrival_date_week_number          0.000000
# arrival_date_day_of_month         0.000000
# stays_in_weekend_nights           0.000000
# stays_in_week_nights              0.000000
# adults                            0.000000
# children                          0.000034
# babies                            0.000000
# meal                              0.000000
# country                           0.004087
# distribution_channel              0.000000
# is_repeated_guest                 0.000000
# previous_cancellations            0.000000
# previous_bookings_not_canceled    0.000000
# reserved_room_type                0.000000
# assigned_room_type                0.000000
# booking_changes                   0.000000
# deposit_type                      0.000000
# ...

# %%
# 비율이 너무나도 작기 때문에 날립시다!
hotel_df = hotel_df.dropna()

# %%
hotel_df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %%
# 성인이 0인 데이터가 있습니다.
hotel_df[hotel_df['adults'] == 0]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 2224    Resort Hotel            0          1               2015
# 2409    Resort Hotel            0          0               2015
# 3181    Resort Hotel            0         36               2015
# 3684    Resort Hotel            0        165               2015
# 3708    Resort Hotel            0        165               2015
# ...              ...          ...        ...                ...
# 117204    City Hotel            0        296               2017
# 117274    City Hotel            0        276               2017
# 117303    City Hotel            0        291               2017
# 117453    City Hotel            0        159               2017
# 118200    City Hotel            0         10               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 2224              October                        41
# 2409              October                        42
# ...

# %%
hotel_df['people'] = hotel_df['adults'] + hotel_df['children'] + hotel_df['babies']
# Out:
# <ipython-input-30-7b8904ba1394>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_df['people'] = hotel_df['adults'] + hotel_df['children'] + hotel_df['babies']

# %%
# 찐유령
hotel_df[hotel_df['people'] == 0]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 2224    Resort Hotel            0          1               2015
# 2409    Resort Hotel            0          0               2015
# 3181    Resort Hotel            0         36               2015
# 3684    Resort Hotel            0        165               2015
# 3708    Resort Hotel            0        165               2015
# ...              ...          ...        ...                ...
# 115029    City Hotel            0        107               2017
# 115091    City Hotel            0          1               2017
# 116251    City Hotel            0         44               2017
# 116534    City Hotel            0          2               2017
# 117087    City Hotel            0        170               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 2224              October                        41
# 2409              October                        42
# ...

# %%
# 삭제조치!
hotel_df = hotel_df[hotel_df['people'] != 0]

# %%
# 숙박 날짜가 0인 것도 있습니다!
hotel_df['total_night'] = hotel_df['stays_in_week_nights'] + hotel_df['stays_in_weekend_nights']
# Out:
# <ipython-input-33-35e1e971b915>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_df['total_night'] = hotel_df['stays_in_week_nights'] + hotel_df['stays_in_weekend_nights']

# %%
# 오전 오후만 놀고 갈 수도 있을 거 같다.
# 그래서 지우진 않겠습니다.
hotel_df[hotel_df['total_night'] == 0]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 167     Resort Hotel            0        111               2015
# 168     Resort Hotel            0          0               2015
# 196     Resort Hotel            0          8               2015
# ...              ...          ...        ...                ...
# 115483    City Hotel            0         15               2017
# 117701    City Hotel            0          0               2017
# 118029    City Hotel            0          0               2017
# 118631    City Hotel            0         78               2017
# 118963    City Hotel            0          1               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
# 달을 그냥 전부 다 계절로 바꾸겠습니다.
hotel_df['arrival_date_month'].apply(lambda x : 'spring' if x in ['March', 'April', 'May'] else 'summer' if x in ['June', 'July', 'August'] else 'fall' if x in ['September', 'October', 'November'] else 'winter')
# Out:
# 0         summer
# 1         summer
# 2         summer
# 3         summer
# 4         summer
#            ...
# 119385    summer
# 119386    summer
# 119387    summer
# 119388    summer
# 119389    summer
# Name: arrival_date_month, Length: 118728, dtype: object

# %%
# 파생변수에 저장!
hotel_df['season'] = hotel_df['arrival_date_month'].apply(lambda x : 'spring' if x in ['March', 'April', 'May'] else 'summer' if x in ['June', 'July', 'August'] else 'fall' if x in ['September', 'October', 'November'] else 'winter')
# Out:
# <ipython-input-36-ae6d485f1fc2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_df['season'] = hotel_df['arrival_date_month'].apply(lambda x : 'spring' if x in ['March', 'April', 'May'] else 'summer' if x in ['June', 'July', 'August'] else 'fall' if x in ['September', 'October', 'November'] else 'winter')

# %%
hotel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118728 entries, 0 to 119389
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           118728 non-null  object
#  1   is_canceled                     118728 non-null  int64
#  2   lead_time                       118728 non-null  int64
#  3   arrival_date_year               118728 non-null  int64
#  4   arrival_date_month              118728 non-null  object
#  5   arrival_date_week_number        118728 non-null  int64
#  6   arrival_date_day_of_month       118728 non-null  int64
#  7   stays_in_weekend_nights         118728 non-null  int64
#  8   stays_in_week_nights            118728 non-null  int64
#  9   adults                          118728 non-null  int64
#  10  children                        118728 non-null  float64
#  11  babies                          118728 non-null  int64
# ...

# %%
# 요청한 룸타입과 배정된 룸타입이 같은지 다른지
# 추후 원핫인코딩을 해야하니, 애초에 만들 때 부터 신경써서 해주자!
hotel_df['expected_room_type'] = (hotel_df['reserved_room_type'] == hotel_df['assigned_room_type']).astype(int)

# %%
# 고객의 캔슬률을 파생변수로 만들어보자
hotel_df['cancel_rate'] = hotel_df['previous_cancellations'] / (hotel_df['previous_cancellations'] + hotel_df['previous_bookings_not_canceled'])

# %%
hotel_df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %%
# nan 은 처음 방문한 사람!
# cancel_rate 0.0 인 사람들은 방문한 적은 있지만 캔슬이 없는 경우
hotel_df[hotel_df['cancel_rate'].isna()]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
hotel_df[hotel_df['cancel_rate'] > 0]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 13825   Resort Hotel            0          6               2016
# 13826   Resort Hotel            0          7               2016
# 13827   Resort Hotel            0          8               2016
# 13855   Resort Hotel            0          5               2015
# 13856   Resort Hotel            0          0               2015
# ...              ...          ...        ...                ...
# 111356    City Hotel            0         10               2017
# 111357    City Hotel            0         20               2017
# 111358    City Hotel            0          8               2017
# 111359    City Hotel            0         13               2017
# 111925    City Hotel            1          6               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 13825               March                        13
# 13826                June                        26
# ...

# %%
# 카테고리를 나누기 위해서 그냥 -1 을 넣자!
hotel_df['cancel_rate'] = hotel_df['cancel_rate'].fillna(-1)

# %%
0 / (0+1)
# Out:
# 0.0

# %%
hotel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118728 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           118728 non-null  object
#  1   is_canceled                     118728 non-null  int64
#  2   lead_time                       118728 non-null  int64
#  3   arrival_date_year               118728 non-null  int64
#  4   arrival_date_month              118728 non-null  object
#  5   arrival_date_week_number        118728 non-null  int64
#  6   arrival_date_day_of_month       118728 non-null  int64
#  7   stays_in_weekend_nights         118728 non-null  int64
#  8   stays_in_week_nights            118728 non-null  int64
#  9   adults                          118728 non-null  int64
#  10  children                        118728 non-null  float64
#  11  babies                          118728 non-null  int64
# ...

# %%
# object 들을 전부 원 핫 인코딩을 할텐데,
# 갯수를 세주는 프로그램을 하나 만들어보자!

# 일단 if문으로 비교를 해야하기에, 값을 확인해보자!
hotel_df['customer_type'].dtype == 'O'
# Out:
# True

# %%
obj_list = []

for i in hotel_df.columns:
  if hotel_df[i].dtype == 'O':
    obj_list.append(i)

# %%
obj_list
# Out:
# ['hotel',
#  'arrival_date_month',
#  'meal',
#  'country',
#  'distribution_channel',
#  'reserved_room_type',
#  'assigned_room_type',
#  'deposit_type',
#  'customer_type',
#  'season']

# %%
for i in obj_list:
  print(i, hotel_df[i].nunique())
# Out:
# hotel 2
# arrival_date_month 12
# meal 5
# country 177
# distribution_channel 5
# reserved_room_type 9
# assigned_room_type 11
# deposit_type 3
# customer_type 4
# season 4

# %%
hotel_df['meal'].unique()
# Out:
# array(['BB', 'FB', 'HB', 'SC', 'Undefined'], dtype=object)

# %%
hotel_df.drop(['country', 'meal'], axis = 1, inplace = True)

# %%
# 본 데이터프레임에서 컬럼을 삭제했으니,
# 원 핫 인코딩을 진행할 때 활용할 리스트에서도 해당 요소를 삭제한다.
obj_list.remove('country')
obj_list.remove('meal')

# %%
hotel_df = pd.get_dummies(hotel_df, columns = obj_list)
hotel_df.head()
# Out:
#    is_canceled  lead_time  arrival_date_year  arrival_date_week_number  \
# 0            0        342               2015                        27
# 1            0        737               2015                        27
# 2            0          7               2015                        27
# 3            0         13               2015                        27
# 4            0         14               2015                        27
#
#    arrival_date_day_of_month  stays_in_weekend_nights  stays_in_week_nights  \
# 0                          1                        0                     0
# 1                          1                        0                     0
# 2                          1                        0                     1
# 3                          1                        0                     1
# 4                          1                        0                     2
#
#    adults  children  babies  is_repeated_guest  previous_cancellations  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(hotel_df.drop('is_canceled', axis = 1), hotel_df['is_canceled'], test_size = 0.3, random_state = 49)

# %% [markdown]
# # **2. 앙상블(Ensemble) 모델**

# %% [markdown]
# - 여러개의 머신러닝 모델을 이용해 최적의 답을 찾아내는 기법을 사용하는 모델
# - 보팅(Voting)
#   - 서로 다른 알고리즘 model을 조합해서 사용
#   - 모델에 대해 투표로 결과를 도출
#
# ```
# hard : class를 0, 1로 분류 예측하는 이진 분류 일때 결과 값에 대한 다수 class를 차용
#
# soft : 각각의 확률의 평균값을 계산한 다음 가장 확률이 높은 값으로 결정
# ```
#
# - 배깅(Bagging)
#   - 같은 알고리즘 내에서 다른 sample 조합을 사용
#   - 샘플 중복 생성을 통해 결과를 도출
#   - 대표적으로 Random Forest
# - 부스팅(Boosting)
#   - 약한 학습기들을 순차적으로 학습시켜 강력한 학습기를 만듦
#   - 이전 오차를 보완해가면서 가중치를 부여
#   - 성능이 매우 우수하지만, 잘못된 레이블이나 아웃라이어에 대해 필요이상으로 민감
#   - LightGBM, AdaBoost, Gradient Boosting, XGBoost
#
# - 스태킹(Stacking)
#   - 다양한 개별 모델들을 조합하여 새로운 모델을 생성
#   - 다양한 모델들을 학습시켜 예측 결과를 얻은 다음 다양한 모델들의 예측 결과를 입력으로 새로운 메타 모델을 학습

# %% [markdown]
# # **3. 랜덤 포레스트(Random Forest)**

# %% [markdown]
# - 머신러닝에서 많이 사용되는 앙상블 기법 중 하나이며 결정 트리를 기반으로 함
# - 학습을 통해 구성해 놓은 결정 트리로부터 분류 결과를 취합해서 결론을 얻는 방식
# - 성능은 꽤 우수한 편이나 오버피팅 하는 경향이 있음

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
pred1 = rf.predict(X_test)
pred1
# Out:
# array([0, 0, 0, ..., 0, 1, 0])

# %%
proba1 = rf.predict_proba(X_test)
proba1
# Out:
# array([[0.96408451, 0.03591549],
#        [0.85      , 0.15      ],
#        [0.99      , 0.01      ],
#        ...,
#        [0.81      , 0.19      ],
#        [0.        , 1.        ],
#        [0.84      , 0.16      ]])

# %%
# 모든 테스트 데이터에 대한 호텔 예약을 취소할 확률만 출력
proba1[:, 1]
# Out:
# array([0.03591549, 0.15      , 0.01      , ..., 0.19      , 1.        ,
#        0.16      ])

# %% [markdown]
# ### 3-1. 머신러닝, 딥러닝에서 모델의 성능을 평가하는데 사용하는 측정값
# - Accuracy : 올바른 예측의 비율
# - Precision(정밀도) : 모델에서 수행한 총 긍정 예측 수에 대한 참 긍정 예측의 비율
# - Recall(재현율) : 실제 긍정 사례의 총 수에 대한 참 긍정 예측의 비율
# - F1 Score : 정밀도와 재현율의 조화 평균이며 정밀도와 재현율 간의 균형을 맞추기 위한 단일 메트릭으로 사용
# - AUC-ROC Curve(Area Under the Recevier Operating Characteristic) : 곡선은 이진 분류 문제에 대한 성능 메트릭. 참양성률과 가양성률 간의 균형을 측정
#   - ROC Curve : 이진 분류의 성능을 측정하는 도구
#   - AUC : ROC 커브와 직선 사이의 면적을 의미. 범위는 0.5 ~ 1 이며 값이 클수록 예측 정확도가 높음
#
# ```
# TPR(True Positive Rate) : 민감도
# 참인 양성 비율
# 실제값은 양성이고 양성으로 잘 분류
# TP / FN + TP
#
# FPR(False Positive Rate) : 특이도
# 거짓 양성 비율
# 실제값은 음성이지만 양성으로 잘못 분류
# FP / TN + FP
# ```

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score

# %%
accuracy_score(y_test, pred1)
# Out:
# 0.8591201325135461

# %%
confusion_matrix(y_test, pred1)
# Out:
# array([[20666,  1644],
#        [ 3374,  9935]])

# %%
print(classification_report(y_test, pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.93      0.89     22310
#            1       0.86      0.75      0.80     13309
#
#     accuracy                           0.86     35619
#    macro avg       0.86      0.84      0.85     35619
# weighted avg       0.86      0.86      0.86     35619

# %%
roc_auc_score(y_test, proba1[:, 1])
# Out:
# 0.927925248091438

# %%
import matplotlib.pyplot as plt
from sklearn.metrics._plot.roc_curve import roc_curve

# %%
# threshold
fpr, tpr, thr = roc_curve(y_test, proba1[:, 1])
# print(fpr)
# print(tpr)
# print(thr)
plt.plot(fpr, tpr)

# %%
# 출신은 의사결정나무! 가지치기를 진행하자!
rf2 = RandomForestClassifier(max_depth = 30, random_state=49)
rf2.fit(X_train, y_train)
proba2 = rf2.predict_proba(X_test)
roc_auc_score(y_test, proba2[:, 1])
# Out:
# 0.9290521365768636

# %%
# 하이퍼 파라미터 적용 전 - 하이퍼 파라미터 적용 후
0.927925248091438 - 0.9290521365768636
# Out:
# -0.0011268884854256367

# %%
# depth 50 일 때
rf3 = RandomForestClassifier(max_depth = 50, random_state=49)
rf3.fit(X_train, y_train)
proba3 = rf3.predict_proba(X_test)
roc_auc_score(y_test, proba3[:, 1])
# Out:
# 0.9277203773399227

# %%
# min_samples_split 샘플 나누는 갯수가 최소 5개는 되어야한다.

rf4 = RandomForestClassifier(min_samples_split = 5, random_state=49)
rf4.fit(X_train, y_train)
proba4 = rf4.predict_proba(X_test)
roc_auc_score(y_test, proba4[:, 1])
# Out:
# 0.9279470196712765

# %%
rf5 = RandomForestClassifier(min_samples_split = 10, random_state=49)
rf5.fit(X_train, y_train)
proba5 = rf5.predict_proba(X_test)
roc_auc_score(y_test, proba5[:, 1])
# Out:
# 0.9262224172067857

# %%
# 최적의 하이퍼 파라미터 두 개를 합쳐준다고 해서 좋은 것은 또 아니다!

# %% [markdown]
# ### 3-2. 하이퍼 파라미터 최적의 값을 찾는 방법
# - GridSearchCV : 원하는 모든 하이퍼 파라미터를 적용하여 최적의 값을 찾음
# - RandomizedsearchCV : 원하는 하이퍼 파라미터를 지정하고 n_iter값을 설정하여 해당 수 만큼 random하게 조합하여 최적의 값을 찾음

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
params = {
    'max_depth' : [None, 10, 30, 50],
    'min_samples_split' : [None, 3, 5, 7, 10]
}

# %%
rf6 = RandomForestClassifier(random_state = 10)

# %%
grid = GridSearchCV(rf6, params, cv=5)

# %%
grid.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 20 fits failed out of a total of 100.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 20 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 340, in fit
#     self._validate_params()
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 600, in _validate_params
#     validate_parameter_constraints(
# ...

# %%
grid.best_params_
# Out:
# {'max_depth': 30, 'min_samples_split': 3}

# %%
# grid 가 추천해준 하이퍼 파라미터로 학습!
rf7 = RandomForestClassifier(min_samples_split = 3, max_depth=30, random_state=49)
rf7.fit(X_train, y_train)
proba7 = rf7.predict_proba(X_test)
roc_auc_score(y_test, proba7[:, 1])
# Out:
# 0.9291036245361142

# %%
rf8 = RandomForestClassifier(random_state = 49)

# %%
rand = RandomizedSearchCV(rf8, params, n_iter = 10, random_state = 49)

# %%
rand.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 5 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 340, in fit
#     self._validate_params()
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 600, in _validate_params
#     validate_parameter_constraints(
# ...

# %%
rand.best_params_
# Out:
# {'min_samples_split': 3, 'max_depth': 30}

# %%
rand.cv_results_
# Out:
# {'mean_fit_time': array([7.55805583, 7.60676208, 4.39308901, 4.28191271, 7.88637862,
#         4.32053165, 8.23198662, 7.8884757 , 8.20537019, 0.02084832]),
#  'std_fit_time': array([0.2579038 , 0.37659061, 0.32939243, 0.22656025, 0.21919952,
#         0.29256738, 0.23820071, 0.30746601, 0.35401596, 0.0004868 ]),
#  'mean_score_time': array([0.3031301 , 0.305966  , 0.1442584 , 0.15278683, 0.32841144,
#         0.1463913 , 0.33625112, 0.31850948, 0.33636031, 0.        ]),
#  'std_score_time': array([0.00758478, 0.00357782, 0.00288634, 0.01612171, 0.00846436,
#         0.00547347, 0.00805822, 0.00537572, 0.0039655 , 0.        ]),
#  'param_min_samples_split': masked_array(data=[10, 10, 10, 3, 7, 5, 5, 7, 3, None],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_depth': masked_array(data=[30, 50, 10, 10, 50, 10, 50, None, 30, None],
# ...

# %% [markdown]
# ### 3-3. 피처 중요도(Feature Importances)
# - Decision Tree에서 노드를 분기할 때 해당 피처가 클래스를 나누는데 얼마나 영향을 미쳤는지를 표기하는 척도
# - 0에 가까우면 클래스를 구분하는데 해당 피처의 영향이 거의 없다는 것이며, 1에 가까우면 해당 피처가 클래스를 나누는데 영향을 많이 줬다는 의미

# %%
proba7 = rf7.predict_proba(X_test)
proba7
# Out:
# array([[0.96146552, 0.03853448],
#        [0.82735875, 0.17264125],
#        [0.96393233, 0.03606767],
#        ...,
#        [0.84951629, 0.15048371],
#        [0.00517321, 0.99482679],
#        [0.88257281, 0.11742719]])

# %%
roc_auc_score(y_test, proba7[:, 1])
# Out:
# 0.9291036245361142

# %%
# 종속변수 빼고 모든 Feature
rf7.feature_importances_
# Out:
# array([1.19152756e-01, 2.12403001e-02, 4.50046402e-02, 5.68239239e-02,
#        2.06125467e-02, 3.03444195e-02, 9.81779099e-03, 5.24684651e-03,
#        8.76129145e-04, 1.92711453e-03, 2.68906834e-02, 3.03664255e-03,
#        2.07469342e-02, 3.07088939e-03, 8.98739623e-02, 2.40363335e-02,
#        6.01865191e-02, 1.29335054e-02, 3.55453898e-02, 3.17035177e-02,
#        3.48840531e-02, 7.16339931e-03, 7.33392655e-03, 3.35940502e-03,
#        3.83758012e-03, 1.98634153e-03, 2.55555002e-03, 1.83051996e-03,
#        3.77025739e-03, 3.58101821e-03, 2.97593635e-03, 3.55731897e-03,
#        2.48771638e-03, 2.90270487e-03, 2.82484326e-03, 3.12219950e-03,
#        7.60071750e-03, 2.96154059e-04, 1.27707032e-02, 9.11982648e-08,
#        5.40053613e-03, 8.65593403e-04, 6.20885719e-04, 4.09847736e-03,
#        2.36417344e-03, 1.12448720e-03, 1.05074800e-03, 3.81028523e-04,
#        3.40311831e-05, 9.32213485e-03, 1.43002834e-03, 1.07513803e-03,
# ...

# %%
hotel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118728 entries, 0 to 119389
# Data columns (total 72 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   is_canceled                     118728 non-null  int64
#  1   lead_time                       118728 non-null  int64
#  2   arrival_date_year               118728 non-null  int64
#  3   arrival_date_week_number        118728 non-null  int64
#  4   arrival_date_day_of_month       118728 non-null  int64
#  5   stays_in_weekend_nights         118728 non-null  int64
#  6   stays_in_week_nights            118728 non-null  int64
#  7   adults                          118728 non-null  int64
#  8   children                        118728 non-null  float64
#  9   babies                          118728 non-null  int64
#  10  is_repeated_guest               118728 non-null  int64
#  11  previous_cancellations          118728 non-null  int64
# ...

# %%
feat_imp = pd.DataFrame({
    'features' : X_train.columns,
    'importances' : rf7.feature_importances_
})

# %%
feat_imp
# Out:
#                          features  importances
# 0                       lead_time     0.119153
# 1               arrival_date_year     0.021240
# 2        arrival_date_week_number     0.045005
# 3       arrival_date_day_of_month     0.056824
# 4         stays_in_weekend_nights     0.020613
# ..                            ...          ...
# 66  customer_type_Transient-Party     0.011337
# 67                    season_fall     0.003493
# 68                  season_spring     0.003818
# 69                  season_summer     0.004333
# 70                  season_winter     0.003525
#
# [71 rows x 2 columns]

# %%
top10 = feat_imp.sort_values('importances', ascending = False).head(10)
top10
# Out:
#                      features  importances
# 0                   lead_time     0.119153
# 61    deposit_type_Non Refund     0.092820
# 60    deposit_type_No Deposit     0.090859
# 14                        adr     0.089874
# 16  total_of_special_requests     0.060187
# 3   arrival_date_day_of_month     0.056824
# 2    arrival_date_week_number     0.045005
# 18                total_night     0.035545
# 20                cancel_rate     0.034884
# 19         expected_room_type     0.031704

# %%
pd.set_option('display.max_rows', 100)

# %%
feat_imp
# Out:
#                           features   importances
# 0                        lead_time  1.191528e-01
# 1                arrival_date_year  2.124030e-02
# 2         arrival_date_week_number  4.500464e-02
# 3        arrival_date_day_of_month  5.682392e-02
# 4          stays_in_weekend_nights  2.061255e-02
# 5             stays_in_week_nights  3.034442e-02
# 6                           adults  9.817791e-03
# 7                         children  5.246847e-03
# 8                           babies  8.761291e-04
# 9                is_repeated_guest  1.927115e-03
# 10          previous_cancellations  2.689068e-02
# 11  previous_bookings_not_canceled  3.036643e-03
# 12                 booking_changes  2.074693e-02
# 13            days_in_waiting_list  3.070889e-03
# 14                             adr  8.987396e-02
# 15     required_car_parking_spaces  2.403633e-02
# 16       total_of_special_requests  6.018652e-02
# 17                          people  1.293351e-02
# ...

# %%
sns.barplot(x = 'importances', y='features', data = top10)
# Out:
# <Axes: xlabel='importances', ylabel='features'>
